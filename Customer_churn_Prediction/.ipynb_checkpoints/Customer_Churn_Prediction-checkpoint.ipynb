# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# ...

# %%
df['Churn'].value_counts(sort = False)
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
# df to plot
labels =df['Churn'].value_counts(sort = False).index
sizes = df['Churn'].value_counts(sort = False)


colors = ["whitesmoke","orange"]
explode = (0.1,0)  # explode 1st slice
 
rcParams['figure.figsize'] = 8,8
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=270,)

plt.title('Percent of churn in customer')
plt.show()

# %%
#missing df
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_df = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_df.head(6)
# Out:
#                 Total  Percent
# Churn               0      0.0
# OnlineSecurity      0      0.0
# gender              0      0.0
# SeniorCitizen       0      0.0
# Partner             0      0.0
# Dependents          0      0.0

# %%
df['Male'] = df['gender'].map(lambda s :1 if s == 'Male' else 0)
df['Female'] = df['gender'].map(lambda s :1 if s == 'Female' else 0)
df.drop(['gender'], axis=1, inplace=True)

# %%
df[['Male','Female']].head()
# Out:
#    Male  Female
# 0     0       1
# 1     1       0
# 2     1       0
# 3     1       0
# 4     0       1

# %%
df['Dependents'] = df['Dependents'].map(lambda s :1  if s =='Yes' else 0)
df['PhoneService'] = df['PhoneService'].map(lambda s :1  if s =='Yes' else 0)

df['PaperlessBilling'] = df['PaperlessBilling'].map(lambda s :1  if s =='Yes' else 0)
df['Churn'] = df['Churn'].map(lambda s :1  if s =='Yes' else 0)

# %%
# tenure distibution 
g = sns.kdeplot(df.tenure[(df["Churn"] == 0) ], color="Red", shade = True)
g = sns.kdeplot(df.tenure[(df["Churn"] == 1) ], ax =g, color="Blue", shade= True)
g.set_xlabel("tenure")
g.set_ylabel("Frequency")
plt.title('Distribution of tenure comparing with churn feature')
g = g.legend(["Not Churn","Churn"])

# %%
df['MultipleLines'].replace('No phone service','No', inplace=True)
df['MultipleLines'] = df['MultipleLines'].map(lambda s :1  if s =='Yes' else 0)
df['Has_InternetService'] = df['InternetService'].map(lambda s :0  if s =='No' else 1)
df['Fiber_optic'] = df['InternetService'].map(lambda s :1  if s =='Fiber optic' else 0)
df['DSL'] = df['InternetService'].map(lambda s :1  if s =='DSL' else 0)
df['OnlineSecurity'] = df['OnlineSecurity'].map(lambda s :1  if s =='Yes' else 0)
df['OnlineBackup'] = df['OnlineBackup'].map(lambda s :1  if s =='Yes' else 0)
df['DeviceProtection'] = df['DeviceProtection'].map(lambda s :1  if s =='Yes' else 0)
df['TechSupport'] = df['TechSupport'].map(lambda s :1  if s =='Yes' else 0)
df['StreamingTV'] = df['StreamingTV'].map(lambda s :1  if s =='Yes' else 0)
df['StreamingMovies'] = df['StreamingMovies'].map(lambda s :1  if s =='Yes' else 0)

# %%
df.head()
# Out:
#    customerID  SeniorCitizen Partner  Dependents  tenure  PhoneService  \
# 0  7590-VHVEG              0     Yes           0       1             0
# 1  5575-GNVDE              0      No           0      34             1
# 2  3668-QPYBK              0      No           0       2             1
# 3  7795-CFOCW              0      No           0      45             0
# 4  9237-HQITU              0      No           0       2             1
#
#    MultipleLines InternetService  OnlineSecurity  OnlineBackup ...   \
# 0              0             DSL               0             1 ...
# 1              0             DSL               1             0 ...
# 2              0             DSL               1             1 ...
# 3              0             DSL               1             0 ...
# 4              0     Fiber optic               0             0 ...
#
#    PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# ...

# %%
df['PaymentMethod'].value_counts()
df = pd.get_dummies(data=df, columns=['PaymentMethod'])
df[['PaymentMethod_Electronic check',
      'PaymentMethod_Mailed check',
      'PaymentMethod_Bank transfer (automatic)',
      'PaymentMethod_Credit card (automatic)']].head()
# Out:
#    PaymentMethod_Electronic check  PaymentMethod_Mailed check  \
# 0                               1                           0
# 1                               0                           1
# 2                               0                           1
# 3                               0                           0
# 4                               1                           0
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        1
# 4                                        0
#
#    PaymentMethod_Credit card (automatic)
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0

# %%
df['Contract'].value_counts()
df = pd.get_dummies(data=df, columns=['Contract'])
df['MonthlyCharges'].head()
# Out:
# 0    29.85
# 1    56.95
# 2    53.85
# 3    42.30
# 4    70.70
# Name: MonthlyCharges, dtype: float64

# %%
g = sns.factorplot(x="Churn", y = "MonthlyCharges",data = df, kind="box", palette = "Set3")

# %%
df['TotalCharges'].head()
# Out:
# 0      29.85
# 1     1889.5
# 2     108.15
# 3    1840.75
# 4     151.65
# Name: TotalCharges, dtype: object

# %%
df[df['TotalCharges'] == " "]
# Out:
#       customerID  SeniorCitizen Partner  Dependents  tenure  PhoneService  \
# 488   4472-LVYGI              0     Yes           1       0             0
# 753   3115-CZMZD              0      No           1       0             1
# 936   5709-LVOEQ              0     Yes           1       0             1
# 1082  4367-NUYAO              0     Yes           1       0             1
# 1340  1371-DWPAZ              0     Yes           1       0             0
# 3331  7644-OMVMY              0     Yes           1       0             1
# 3826  3213-VVOLG              0     Yes           1       0             1
# 4380  2520-SGTTA              0     Yes           1       0             1
# 5218  2923-ARZLG              0     Yes           1       0             1
# 6670  4075-WKNIU              0     Yes           1       0             1
# 6754  2775-SEFEE              0      No           1       0             1
#
#       MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
## Drop missing df
df = df[df['TotalCharges'] != " "]
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'])
g = sns.factorplot(y="TotalCharges",x="Churn",data=df,kind="violin", palette = "Set2")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 30 columns):
# customerID                                 7032 non-null object
# SeniorCitizen                              7032 non-null int64
# Partner                                    7032 non-null object
# Dependents                                 7032 non-null int64
# tenure                                     7032 non-null int64
# PhoneService                               7032 non-null int64
# MultipleLines                              7032 non-null int64
# InternetService                            7032 non-null object
# OnlineSecurity                             7032 non-null int64
# OnlineBackup                               7032 non-null int64
# DeviceProtection                           7032 non-null int64
# TechSupport                                7032 non-null int64
# StreamingTV                                7032 non-null int64
# ...

# %%
df.drop(['InternetService'], axis=1, inplace=True)
df['Partner'] = df['Partner'].map(lambda s :1  if s =='Yes' else 0)

# %%
df.drop(['customerID'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 28 columns):
# SeniorCitizen                              7032 non-null int64
# Partner                                    7032 non-null int64
# Dependents                                 7032 non-null int64
# tenure                                     7032 non-null int64
# PhoneService                               7032 non-null int64
# MultipleLines                              7032 non-null int64
# OnlineSecurity                             7032 non-null int64
# OnlineBackup                               7032 non-null int64
# DeviceProtection                           7032 non-null int64
# TechSupport                                7032 non-null int64
# StreamingTV                                7032 non-null int64
# StreamingMovies                            7032 non-null int64
# PaperlessBilling                           7032 non-null int64
# ...

# %%
df["Churn"] = df["Churn"].astype(int)

Y_train = df["Churn"]
X_train = df.drop(labels = ["Churn"],axis = 1)

# %%
from sklearn.model_selection import  cross_val_score,GridSearchCV,RandomizedSearchCV
from sklearn.metrics import roc_auc_score


def CalculateScore(clf, X_train, Y_train):
    
    # 10 Folds Cross Validation 
    clf_score = cross_val_score(clf, X_train, Y_train, cv=10)
    clf_score.mean()
  
    
    print( "Model Result\n" +
           "Accuracy of " + str(clf.__class__.__name__) + " :\n "
           "\nCross Val Score : " + str(clf_score.mean()))

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(random_state=15)
tree.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=15,
#             splitter='best')

# %%
CalculateScore(tree, X_train, Y_train)
# Out:
# Model Result
# Accuracy of DecisionTreeClassifier :
#
# Cross Val Score : 0.7251162766787768

# %%
param_grid  = { 
               'min_samples_split': [2, 4, 6, 10, 15, 25],
               'min_samples_leaf': range(1,25,2),
                'max_depth': range(1,20,1),
                'splitter' : ('best', 'random'),
                 'class_weight':[{1: w} for w in [1,1.5,2,2.5]]
                }

tree = GridSearchCV(DecisionTreeClassifier(random_state=15), param_grid)

tree.fit(X_train, Y_train)
#tree_preds = tree.predict_proba(X_test)[:, 1]
#tree_performance = roc_auc_score(Y_test, tree_preds)

print(
    #'DecisionTree: Area under the ROC curve = {}'.format(tree_performance)
     "\nBest parameters \n" + str(tree.best_params_))
# Out:
# Best parameters
# {'class_weight': {1: 1}, 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}

# %%
dtree = DecisionTreeClassifier(random_state=15,**tree.best_params_)

dtree.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(class_weight={1: 1}, criterion='gini', max_depth=6,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=15,
#             splitter='random')

# %%
CalculateScore(dtree, X_train, Y_train)
# Out:
# Model Result
# Accuracy of DecisionTreeClassifier :
#
# Cross Val Score : 0.7893925814156078

# %%
dtree_fea = pd.DataFrame(dtree.feature_importances_)
dtree_fea["name"] = list(X_train) 
dtree_fea.sort_values(by=0, ascending=False).head()
# Out:
#            0                     name
# 24  0.517928  Contract_Month-to-month
# 18  0.170562              Fiber_optic
# 3   0.144707                   tenure
# 14  0.052734             TotalCharges
# 19  0.021255                      DSL

# %%
from sklearn.ensemble import RandomForestClassifier

Rfclf = RandomForestClassifier(random_state=15)
Rfclf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=15, verbose=0, warm_start=False)

# %%
CalculateScore(Rfclf, X_train, Y_train)
# Out:
# Model Result
# Accuracy of RandomForestClassifier :
#
# Cross Val Score : 0.7844106770093612

# %%
# %%time
param_grid  = { 
                'n_estimators' : [500,1200],
                'max_depth': range(1,14,2),
                'max_features' : ('log2', 'sqrt'),
              }

GridRF = GridSearchCV(RandomForestClassifier(random_state=15), param_grid)

GridRF.fit(X_train, Y_train)
#RF_preds = GridRF.predict_proba(X_test)[:, 1]
#RF_performance = roc_auc_score(Y_test, RF_preds)

print(
    #'DecisionTree: Area under the ROC curve = {}'.format(RF_performance)
     "\nBest parameters \n" + str(GridRF.best_params_))
# Out:
# Best parameters
# {'max_depth': 9, 'max_features': 'sqrt', 'n_estimators': 500}
# Wall time: 4min 16s

# %%
rf = RandomForestClassifier(random_state=15,**GridRF.best_params_)
rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=9, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#             oob_score=False, random_state=15, verbose=0, warm_start=False)

# %%
CalculateScore(rf, X_train, Y_train)
# Out:
# Model Result
# Accuracy of RandomForestClassifier :
#
# Cross Val Score : 0.8041798578805157

# %%
Rfclf_fea = pd.DataFrame(rf.feature_importances_)
Rfclf_fea["name"] = list(X_train) 
Rfclf_fea.sort_values(by=0, ascending=False).head()
# Out:
#            0                     name
# 3   0.172163                   tenure
# 14  0.136200             TotalCharges
# 24  0.132340  Contract_Month-to-month
# 13  0.113011           MonthlyCharges
# 18  0.080364              Fiber_optic
